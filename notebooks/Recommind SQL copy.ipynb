# %%
# Data treatment

import numpy as np # linear algebra
import polars as pl # data processing, CSV file I/O (e.g. pd.read_csv)
import pandas as pd
import duckdb

# OS and Dotenv

from dotenv import load_dotenv
import os
load_dotenv()  

# Deep Learning

import torch                  
import torch.nn as nn          
import torch.nn.functional as F  
import torch.optim as optim  
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import DataLoader, Dataset, TensorDataset

# GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def data_treatment(df):

    df['categories'] = df['categories'].str.replace('[', '', regex=False).str.replace(']', '', regex=False)
    df['authors'] = df['authors'].str.replace('[', '', regex=False).str.replace(']', '', regex=False)
    df['categories'] = df['categories'].fillna('No Category')
    df['ratingsCount'] = df['ratingsCount'].fillna(0)

    return df

# %%
import duckdb
import polars as pl
from dotenv import load_dotenv
import os
load_dotenv()  


# Conexão e query
con = duckdb.connect("proto.duckdb")

query = """SELECT 
    b.Title, 
    b.authors, 
    b.categories, 
    r.Id, 
    r.User_id, 
    r."review/score",
    b.ratingsCount
FROM books b
JOIN ratings r ON b.Title = r.Title;"""

df = con.execute(query).fetchdf()

df = data_treatment(df)

json_data = df.to_dict(orient="records")

payload = {
    'data' : json_data,
    'user' : 212393
}
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
df
# Out:
#                        Title              authors         categories  \
# 0             Never Cry Wolf       'Farley Mowat'  'Animal behavior'
# 1             Never Cry Wolf       'Farley Mowat'  'Animal behavior'
# 2             Never Cry Wolf       'Farley Mowat'  'Animal behavior'
# 3             Never Cry Wolf       'Farley Mowat'  'Animal behavior'
# 4             Never Cry Wolf       'Farley Mowat'  'Animal behavior'
# ...                      ...                  ...                ...
# 2999787  The Idea of History  'R. G. Collingwood'          'History'
# 2999788  The Idea of History  'R. G. Collingwood'          'History'
# 2999789  The Idea of History  'R. G. Collingwood'          'History'
# 2999790  The Idea of History  'R. G. Collingwood'          'History'
# 2999791  The Idea of History  'R. G. Collingwood'          'History'
#
#                  Id         User_id  review/score  ratingsCount
# 0        0316586390  A3D5EO8SCPTX9W           5.0          34.0
# 1        0316586390  A24N8O90K345KV           5.0          34.0
# 2        0316586390  A2CF0A2HR4OS22           5.0          34.0
# 3        0316586390            None           5.0          34.0
# 4        0316586390  A1VXA74UYHCT9E           1.0          34.0
# ...             ...             ...           ...           ...
# 2999787  B000NSLVCU            None           4.0           3.0
# 2999788  B000NSLVCU  A1SMUB9ASL5L9Y           4.0           3.0
# 2999789  B000NSLVCU  A2AQMEKZKK5EE4           4.0           3.0
# 2999790  B000NSLVCU  A18SQGYBKS852K           5.0           3.0
# 2999791  B000NSLVCU            None           1.0           3.0
#
# [2999792 rows x 7 columns]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
payload
# Out:
# {'data': [{'Title': 'The coming race',
#    'authors': "'Edward Bulwer-Lytton'",
#    'categories': 'No Category',
#    'Id': 'B0007EKQS0',
#    'User_id': 'AS66VOYLSRMBN',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'The coming race',
#    'authors': "'Edward Bulwer-Lytton'",
#    'categories': 'No Category',
#    'Id': 'B0007EKQS0',
#    'User_id': 'A25DO4LKI6AZ9',
#    'review/score': 3.0,
#    'ratingsCount': 0.0},
#   {'Title': 'The coming race',
#    'authors': "'Edward Bulwer-Lytton'",
#    'categories': 'No Category',
#    'Id': 'B0007EKQS0',
#    'User_id': 'A27DHFFWMH042Y',
#    'review/score': 4.0,
#    'ratingsCount': 0.0},
#   {'Title': 'The coming race',
#    'authors': "'Edward Bulwer-Lytton'",
#    'categories': 'No Category',
#    'Id': 'B0007EKQS0',
#    'User_id': 'A1BZRECABLFF8G',
#    'review/score': 1.0,
#    'ratingsCount': 0.0},
#   {'Title': 'The coming race',
#    'authors': "'Edward Bulwer-Lytton'",
#    'categories': 'No Category',
#    'Id': 'B0007EKQS0',
#    'User_id': 'A2RZ7I99IMLVV6',
#    'review/score': 2.0,
#    'ratingsCount': 0.0},
#   {'Title': 'The coming race',
#    'authors': "'Edward Bulwer-Lytton'",
#    'categories': 'No Category',
#    'Id': 'B0007EKQS0',
#    'User_id': 'AD5DEGVV48016',
#    'review/score': 2.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Overheard in a Garden',
#    'authors': "'Oliver Herford'",
#    'categories': 'No Category',
#    'Id': 'B000867OG4',
#    'User_id': 'A15RP6DBV46OI0',
#    'review/score': 4.0,
#    'ratingsCount': 0.0},
#   {'Title': 'The Fox on the Box (A School Zone Start to Read Book, Ages 4-7, Level 1)',
#    'authors': "'Barbara Gregorich'",
#    'categories': "'Juvenile Fiction'",
#    'Id': '0887434037',
#    'User_id': None,
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'The Fox on the Box (A School Zone Start to Read Book, Ages 4-7, Level 1)',
#    'authors': "'Barbara Gregorich'",
#    'categories': "'Juvenile Fiction'",
#    'Id': '0887434037',
#    'User_id': None,
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'The Fox on the Box (A School Zone Start to Read Book, Ages 4-7, Level 1)',
#    'authors': "'Barbara Gregorich'",
#    'categories': "'Juvenile Fiction'",
#    'Id': '0887434037',
#    'User_id': 'A1ATL0HX0QRPDK',
#    'review/score': 3.0,
#    'ratingsCount': 0.0},
#   {'Title': 'The Fox on the Box (A School Zone Start to Read Book, Ages 4-7, Level 1)',
#    'authors': "'Barbara Gregorich'",
#    'categories': "'Juvenile Fiction'",
#    'Id': '0887434037',
#    'User_id': 'A1YZQGOR1S4G7S',
#    'review/score': 4.0,
#    'ratingsCount': 0.0},
#   {'Title': 'The Fox on the Box (A School Zone Start to Read Book, Ages 4-7, Level 1)',
#    'authors': "'Barbara Gregorich'",
#    'categories': "'Juvenile Fiction'",
#    'Id': '0887434037',
#    'User_id': 'A1W415JP5WEAJK',
#    'review/score': 3.0,
#    'ratingsCount': 0.0},
#   {'Title': 'The Fox on the Box (A School Zone Start to Read Book, Ages 4-7, Level 1)',
#    'authors': "'Barbara Gregorich'",
#    'categories': "'Juvenile Fiction'",
#    'Id': '0887434037',
#    'User_id': 'AJ7XVLWA630N7',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'The Fox on the Box (A School Zone Start to Read Book, Ages 4-7, Level 1)',
#    'authors': "'Barbara Gregorich'",
#    'categories': "'Juvenile Fiction'",
#    'Id': '0887434037',
#    'User_id': 'A3LCTPPOF0LN44',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'The Fox on the Box (A School Zone Start to Read Book, Ages 4-7, Level 1)',
#    'authors': "'Barbara Gregorich'",
#    'categories': "'Juvenile Fiction'",
#    'Id': '0887434037',
#    'User_id': 'A2N2ZEYKEGG60S',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'The Fox on the Box (A School Zone Start to Read Book, Ages 4-7, Level 1)',
#    'authors': "'Barbara Gregorich'",
#    'categories': "'Juvenile Fiction'",
#    'Id': '0887434037',
#    'User_id': 'A2Z8EYDIKGZRS9',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': "A people's tragedy : the Russian Revolution, 1891-1924",
#    'authors': "'Orlando Figes', 'Professor Orlando Figes', 'Figes'",
#    'categories': "'History'",
#    'Id': 'B00005WLKF',
#    'User_id': 'A2MV0KBXMSI96Q',
#    'review/score': 5.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Scientist and Catholic: Pierre Duhem',
#    'authors': "'Stanley L. Jaki'",
#    'categories': "'Religion'",
#    'Id': '0931888441',
#    'User_id': 'A2O91QKXP35684',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Scientist and Catholic: Pierre Duhem',
#    'authors': "'Stanley L. Jaki'",
#    'categories': "'Religion'",
#    'Id': '0931888441',
#    'User_id': 'A3JD9S9XMSTFLU',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Scientist and Catholic: Pierre Duhem',
#    'authors': "'Stanley L. Jaki'",
#    'categories': "'Religion'",
#    'Id': '0931888441',
#    'User_id': 'AY068D04AWR18',
#    'review/score': 2.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Brave Pig (Step into Reading, Step 1, paper)',
#    'authors': "'Shana Corey'",
#    'categories': "'Juvenile Fiction'",
#    'Id': '0375802045',
#    'User_id': 'AFFAFJ5BQJ5GF',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Dying to Be Thin: Understanding and Defeating Anorexia Nervosa and Bulimia--A Practical, Lifesaving Guide',
#    'authors': "'Ira M. Sacker', 'Marc A. Zimmer'",
#    'categories': "'Self-Help'",
#    'Id': '0446384178',
#    'User_id': 'A1SACSEF3OHD76',
#    'review/score': 4.0,
#    'ratingsCount': 2.0},
#   {'Title': 'Dying to Be Thin: Understanding and Defeating Anorexia Nervosa and Bulimia--A Practical, Lifesaving Guide',
#    'authors': "'Ira M. Sacker', 'Marc A. Zimmer'",
#    'categories': "'Self-Help'",
#    'Id': '0446384178',
#    'User_id': None,
#    'review/score': 5.0,
#    'ratingsCount': 2.0},
#   {'Title': 'Dying to Be Thin: Understanding and Defeating Anorexia Nervosa and Bulimia--A Practical, Lifesaving Guide',
#    'authors': "'Ira M. Sacker', 'Marc A. Zimmer'",
#    'categories': "'Self-Help'",
#    'Id': '0446384178',
#    'User_id': None,
#    'review/score': 5.0,
#    'ratingsCount': 2.0},
#   {'Title': 'Dying to Be Thin: Understanding and Defeating Anorexia Nervosa and Bulimia--A Practical, Lifesaving Guide',
#    'authors': "'Ira M. Sacker', 'Marc A. Zimmer'",
#    'categories': "'Self-Help'",
#    'Id': '0446384178',
#    'User_id': 'A28WJUJF6D2ULA',
#    'review/score': 4.0,
#    'ratingsCount': 2.0},
#   {'Title': 'Dying to Be Thin: Understanding and Defeating Anorexia Nervosa and Bulimia--A Practical, Lifesaving Guide',
#    'authors': "'Ira M. Sacker', 'Marc A. Zimmer'",
#    'categories': "'Self-Help'",
#    'Id': '0446384178',
#    'User_id': 'A3F0IYTB1Z4II1',
#    'review/score': 4.0,
#    'ratingsCount': 2.0},
#   {'Title': 'Complete Origami/an A-Z of Facts and Folds, With Step-By-Step Instructions for over 100 Projects',
#    'authors': "'Eric Kenneway'",
#    'categories': "'Crafts & Hobbies'",
#    'Id': 'B000Q7XRA2',
#    'User_id': 'A12TY4CLBG4V3K',
#    'review/score': 5.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Complete Origami/an A-Z of Facts and Folds, With Step-By-Step Instructions for over 100 Projects',
#    'authors': "'Eric Kenneway'",
#    'categories': "'Crafts & Hobbies'",
#    'Id': 'B000Q7XRA2',
#    'User_id': 'A1KF4FFG7S5X2F',
#    'review/score': 3.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Complete Origami/an A-Z of Facts and Folds, With Step-By-Step Instructions for over 100 Projects',
#    'authors': "'Eric Kenneway'",
#    'categories': "'Crafts & Hobbies'",
#    'Id': 'B000Q7XRA2',
#    'User_id': 'A5OKLEI18BIR',
#    'review/score': 5.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Complete Origami/an A-Z of Facts and Folds, With Step-By-Step Instructions for over 100 Projects',
#    'authors': "'Eric Kenneway'",
#    'categories': "'Crafts & Hobbies'",
#    'Id': 'B000Q7XRA2',
#    'User_id': 'A1F3D3NEHFE8CZ',
#    'review/score': 4.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Complete Origami/an A-Z of Facts and Folds, With Step-By-Step Instructions for over 100 Projects',
#    'authors': "'Eric Kenneway'",
#    'categories': "'Crafts & Hobbies'",
#    'Id': 'B000Q7XRA2',
#    'User_id': 'A38Y1R032M63B',
#    'review/score': 2.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Complete Origami/an A-Z of Facts and Folds, With Step-By-Step Instructions for over 100 Projects',
#    'authors': "'Eric Kenneway'",
#    'categories': "'Crafts & Hobbies'",
#    'Id': 'B000Q7XRA2',
#    'User_id': 'A28CXWNXNMK175',
#    'review/score': 5.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Complete Origami/an A-Z of Facts and Folds, With Step-By-Step Instructions for over 100 Projects',
#    'authors': "'Eric Kenneway'",
#    'categories': "'Crafts & Hobbies'",
#    'Id': 'B000Q7XRA2',
#    'User_id': 'A4QPUYJRIGM7L',
#    'review/score': 4.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Complete Origami/an A-Z of Facts and Folds, With Step-By-Step Instructions for over 100 Projects',
#    'authors': "'Eric Kenneway'",
#    'categories': "'Crafts & Hobbies'",
#    'Id': 'B000Q7XRA2',
#    'User_id': 'A2513Z1G4AG4P7',
#    'review/score': 4.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Complete Origami/an A-Z of Facts and Folds, With Step-By-Step Instructions for over 100 Projects',
#    'authors': "'Eric Kenneway'",
#    'categories': "'Crafts & Hobbies'",
#    'Id': 'B000Q7XRA2',
#    'User_id': 'AFXTPJOE2D4M3',
#    'review/score': 5.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Complete Origami/an A-Z of Facts and Folds, With Step-By-Step Instructions for over 100 Projects',
#    'authors': "'Eric Kenneway'",
#    'categories': "'Crafts & Hobbies'",
#    'Id': 'B000Q7XRA2',
#    'User_id': 'A3LZMGP3NHWAK',
#    'review/score': 5.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Complete Origami/an A-Z of Facts and Folds, With Step-By-Step Instructions for over 100 Projects',
#    'authors': "'Eric Kenneway'",
#    'categories': "'Crafts & Hobbies'",
#    'Id': 'B000Q7XRA2',
#    'User_id': 'AO2UM3J8273D4',
#    'review/score': 2.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Complete Origami/an A-Z of Facts and Folds, With Step-By-Step Instructions for over 100 Projects',
#    'authors': "'Eric Kenneway'",
#    'categories': "'Crafts & Hobbies'",
#    'Id': 'B000Q7XRA2',
#    'User_id': 'A16U57SHCD2V8Q',
#    'review/score': 5.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Complete Origami/an A-Z of Facts and Folds, With Step-By-Step Instructions for over 100 Projects',
#    'authors': "'Eric Kenneway'",
#    'categories': "'Crafts & Hobbies'",
#    'Id': 'B000Q7XRA2',
#    'User_id': 'A11YHS3A7LJEDW',
#    'review/score': 5.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Complete Origami/an A-Z of Facts and Folds, With Step-By-Step Instructions for over 100 Projects',
#    'authors': "'Eric Kenneway'",
#    'categories': "'Crafts & Hobbies'",
#    'Id': 'B000Q7XRA2',
#    'User_id': 'A20CYMPAKZ3EZK',
#    'review/score': 1.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Complete Origami/an A-Z of Facts and Folds, With Step-By-Step Instructions for over 100 Projects',
#    'authors': "'Eric Kenneway'",
#    'categories': "'Crafts & Hobbies'",
#    'Id': 'B000Q7XRA2',
#    'User_id': 'A3V2I999ZG6K5D',
#    'review/score': 4.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Complete Origami/an A-Z of Facts and Folds, With Step-By-Step Instructions for over 100 Projects',
#    'authors': "'Eric Kenneway'",
#    'categories': "'Crafts & Hobbies'",
#    'Id': 'B000Q7XRA2',
#    'User_id': 'A3FK4PQ805DZHV',
#    'review/score': 3.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Complete Origami/an A-Z of Facts and Folds, With Step-By-Step Instructions for over 100 Projects',
#    'authors': "'Eric Kenneway'",
#    'categories': "'Crafts & Hobbies'",
#    'Id': 'B000Q7XRA2',
#    'User_id': 'A3JH3LIKXHPKE8',
#    'review/score': 5.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Complete Origami/an A-Z of Facts and Folds, With Step-By-Step Instructions for over 100 Projects',
#    'authors': "'Eric Kenneway'",
#    'categories': "'Crafts & Hobbies'",
#    'Id': 'B000Q7XRA2',
#    'User_id': 'A1UJ6960GPWWKH',
#    'review/score': 5.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Complete Origami/an A-Z of Facts and Folds, With Step-By-Step Instructions for over 100 Projects',
#    'authors': "'Eric Kenneway'",
#    'categories': "'Crafts & Hobbies'",
#    'Id': 'B000Q7XRA2',
#    'User_id': 'AO313U8S0MKQ',
#    'review/score': 1.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Complete Origami/an A-Z of Facts and Folds, With Step-By-Step Instructions for over 100 Projects',
#    'authors': "'Eric Kenneway'",
#    'categories': "'Crafts & Hobbies'",
#    'Id': 'B000Q7XRA2',
#    'User_id': 'A1YW79131RD9WC',
#    'review/score': 5.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Complete Origami/an A-Z of Facts and Folds, With Step-By-Step Instructions for over 100 Projects',
#    'authors': "'Eric Kenneway'",
#    'categories': "'Crafts & Hobbies'",
#    'Id': 'B000Q7XRA2',
#    'User_id': 'A28CXWNXNMK175',
#    'review/score': 5.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Complete Origami/an A-Z of Facts and Folds, With Step-By-Step Instructions for over 100 Projects',
#    'authors': "'Eric Kenneway'",
#    'categories': "'Crafts & Hobbies'",
#    'Id': 'B000Q7XRA2',
#    'User_id': 'A37611FPKW2P2O',
#    'review/score': 5.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Complete Origami/an A-Z of Facts and Folds, With Step-By-Step Instructions for over 100 Projects',
#    'authors': "'Eric Kenneway'",
#    'categories': "'Crafts & Hobbies'",
#    'Id': 'B000Q7XRA2',
#    'User_id': 'A3HKUVNW2CK1VE',
#    'review/score': 5.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Complete Origami/an A-Z of Facts and Folds, With Step-By-Step Instructions for over 100 Projects',
#    'authors': "'Eric Kenneway'",
#    'categories': "'Crafts & Hobbies'",
#    'Id': 'B000Q7XRA2',
#    'User_id': 'AG5FCALJW3NWE',
#    'review/score': 5.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Complete Origami/an A-Z of Facts and Folds, With Step-By-Step Instructions for over 100 Projects',
#    'authors': "'Eric Kenneway'",
#    'categories': "'Crafts & Hobbies'",
#    'Id': 'B000Q7XRA2',
#    'User_id': 'A31GEK9IDBTECT',
#    'review/score': 5.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Complete Origami/an A-Z of Facts and Folds, With Step-By-Step Instructions for over 100 Projects',
#    'authors': "'Eric Kenneway'",
#    'categories': "'Crafts & Hobbies'",
#    'Id': 'B000Q7XRA2',
#    'User_id': 'A1PM0NG3V9WFGL',
#    'review/score': 5.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Extremophiles: Microbial Life in Extreme Environments',
#    'authors': "'Koki Horikoshi', 'William D. Grant', 'W. D. Grant'",
#    'categories': "'Science'",
#    'Id': '0471026182',
#    'User_id': 'A2ZDUZY0ETCVQ7',
#    'review/score': 4.0,
#    'ratingsCount': 0.0},
#   {'Title': 'The History of Mary Prince (Turtleback School & Library Binding Edition)',
#    'authors': None,
#    'categories': "'Authors'",
#    'Id': '0613642872',
#    'User_id': 'AEGR7IBHUM3R7',
#    'review/score': 4.0,
#    'ratingsCount': 0.0},
#   {'Title': 'The History of Mary Prince (Turtleback School & Library Binding Edition)',
#    'authors': None,
#    'categories': "'Authors'",
#    'Id': '0613642872',
#    'User_id': 'A3QZCA4LTTVGAD',
#    'review/score': 4.0,
#    'ratingsCount': 0.0},
#   {'Title': 'The History of Mary Prince (Turtleback School & Library Binding Edition)',
#    'authors': None,
#    'categories': "'Authors'",
#    'Id': '0613642872',
#    'User_id': 'A3H771U0X5CH7L',
#    'review/score': 4.0,
#    'ratingsCount': 0.0},
#   {'Title': 'The History of Mary Prince (Turtleback School & Library Binding Edition)',
#    'authors': None,
#    'categories': "'Authors'",
#    'Id': '0613642872',
#    'User_id': 'AHE015C34AYG3',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'The History of Mary Prince (Turtleback School & Library Binding Edition)',
#    'authors': None,
#    'categories': "'Authors'",
#    'Id': '0613642872',
#    'User_id': 'A3DHYFPAI7GDE8',
#    'review/score': 4.0,
#    'ratingsCount': 0.0},
#   {'Title': 'The History of Mary Prince (Turtleback School & Library Binding Edition)',
#    'authors': None,
#    'categories': "'Authors'",
#    'Id': '0613642872',
#    'User_id': 'A31TTY2A3MIIEL',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'WomanWisdom: A Feminist Lectionary and Psalter - Women of the Hebrew Scriptures: Part 1',
#    'authors': None,
#    'categories': 'No Category',
#    'Id': '082451100X',
#    'User_id': 'A2KX0GQC73QPSC',
#    'review/score': 4.0,
#    'ratingsCount': 0.0},
#   {'Title': 'East Timor: A Memoir of the Negotiations for Independence',
#    'authors': "'Jamsheed Marker'",
#    'categories': "'Social Science'",
#    'Id': 'B000MUFIJQ',
#    'User_id': 'AASG63UW57UEU',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': "The ZOO WHERE YOU'RE FED TO GOD: A NOVEL",
#    'authors': "'Michael Ventura'",
#    'categories': "'Fiction'",
#    'Id': '0671892223',
#    'User_id': None,
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': "The ZOO WHERE YOU'RE FED TO GOD: A NOVEL",
#    'authors': "'Michael Ventura'",
#    'categories': "'Fiction'",
#    'Id': '0671892223',
#    'User_id': 'A1IR3G801PV95H',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': "The ZOO WHERE YOU'RE FED TO GOD: A NOVEL",
#    'authors': "'Michael Ventura'",
#    'categories': "'Fiction'",
#    'Id': '0671892223',
#    'User_id': 'A3SN0R53QBA0J2',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': "The ZOO WHERE YOU'RE FED TO GOD: A NOVEL",
#    'authors': "'Michael Ventura'",
#    'categories': "'Fiction'",
#    'Id': '0671892223',
#    'User_id': 'A3MJU0FT2YF0VC',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': "The ZOO WHERE YOU'RE FED TO GOD: A NOVEL",
#    'authors': "'Michael Ventura'",
#    'categories': "'Fiction'",
#    'Id': '0671892223',
#    'User_id': 'A3SN0R53QBA0J2',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': "The ZOO WHERE YOU'RE FED TO GOD: A NOVEL",
#    'authors': "'Michael Ventura'",
#    'categories': "'Fiction'",
#    'Id': '0671892223',
#    'User_id': 'A2TDA3RKYXLX1A',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': "The ZOO WHERE YOU'RE FED TO GOD: A NOVEL",
#    'authors': "'Michael Ventura'",
#    'categories': "'Fiction'",
#    'Id': '0671892223',
#    'User_id': None,
#    'review/score': 1.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Flawless! The Ten Most Common Character Flaws and What You Can Do about Them',
#    'authors': None,
#    'categories': 'No Category',
#    'Id': '0688175910',
#    'User_id': 'ALQS6T510DU4Z',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Flawless! The Ten Most Common Character Flaws and What You Can Do about Them',
#    'authors': None,
#    'categories': 'No Category',
#    'Id': '0688175910',
#    'User_id': 'AR5ZYD2LFSMA8',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Flawless! The Ten Most Common Character Flaws and What You Can Do about Them',
#    'authors': None,
#    'categories': 'No Category',
#    'Id': '0688175910',
#    'User_id': None,
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Flawless! The Ten Most Common Character Flaws and What You Can Do about Them',
#    'authors': None,
#    'categories': 'No Category',
#    'Id': '0688175910',
#    'User_id': 'A1QJRZ7OLKGLZL',
#    'review/score': 2.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Flawless! The Ten Most Common Character Flaws and What You Can Do about Them',
#    'authors': None,
#    'categories': 'No Category',
#    'Id': '0688175910',
#    'User_id': None,
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Flawless! The Ten Most Common Character Flaws and What You Can Do about Them',
#    'authors': None,
#    'categories': 'No Category',
#    'Id': '0688175910',
#    'User_id': 'A1IBC9XP2LICQL',
#    'review/score': 4.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Flawless! The Ten Most Common Character Flaws and What You Can Do about Them',
#    'authors': None,
#    'categories': 'No Category',
#    'Id': '0688175910',
#    'User_id': 'A1I6ZXLKEUKV7W',
#    'review/score': 4.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Flawless! The Ten Most Common Character Flaws and What You Can Do about Them',
#    'authors': None,
#    'categories': 'No Category',
#    'Id': '0688175910',
#    'User_id': None,
#    'review/score': 2.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Flawless! The Ten Most Common Character Flaws and What You Can Do about Them',
#    'authors': None,
#    'categories': 'No Category',
#    'Id': '0688175910',
#    'User_id': None,
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Flawless! The Ten Most Common Character Flaws and What You Can Do about Them',
#    'authors': None,
#    'categories': 'No Category',
#    'Id': '0688175910',
#    'User_id': None,
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Flawless! The Ten Most Common Character Flaws and What You Can Do about Them',
#    'authors': None,
#    'categories': 'No Category',
#    'Id': '0688175910',
#    'User_id': 'A1KKX9ULWOFH8J',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Flawless! The Ten Most Common Character Flaws and What You Can Do about Them',
#    'authors': None,
#    'categories': 'No Category',
#    'Id': '0688175910',
#    'User_id': None,
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Flawless! The Ten Most Common Character Flaws and What You Can Do about Them',
#    'authors': None,
#    'categories': 'No Category',
#    'Id': '0688175910',
#    'User_id': None,
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Flawless! The Ten Most Common Character Flaws and What You Can Do about Them',
#    'authors': None,
#    'categories': 'No Category',
#    'Id': '0688175910',
#    'User_id': 'AR5ZYD2LFSMA8',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Flawless! The Ten Most Common Character Flaws and What You Can Do about Them',
#    'authors': None,
#    'categories': 'No Category',
#    'Id': '0688175910',
#    'User_id': 'AR5ZYD2LFSMA8',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'The Fortune Hunters',
#    'authors': "'Daisy Goodwin'",
#    'categories': "'Fiction'",
#    'Id': 'B000HQQX94',
#    'User_id': 'A89TL80GBGNUK',
#    'review/score': 2.0,
#    'ratingsCount': 26.0},
#   {'Title': 'Icon: Art of the Wine Label',
#    'authors': "'Jeffrey Caldewey', 'Chuck House'",
#    'categories': "'Design'",
#    'Id': '1891267302',
#    'User_id': 'A1SSJYNEYE8HNZ',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Icon: Art of the Wine Label',
#    'authors': "'Jeffrey Caldewey', 'Chuck House'",
#    'categories': "'Design'",
#    'Id': '1891267302',
#    'User_id': 'A24JQHICMKDBTT',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Icon: Art of the Wine Label',
#    'authors': "'Jeffrey Caldewey', 'Chuck House'",
#    'categories': "'Design'",
#    'Id': '1891267302',
#    'User_id': 'AYRYSRXCMCN9H',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Icon: Art of the Wine Label',
#    'authors': "'Jeffrey Caldewey', 'Chuck House'",
#    'categories': "'Design'",
#    'Id': '1891267302',
#    'User_id': None,
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Icon: Art of the Wine Label',
#    'authors': "'Jeffrey Caldewey', 'Chuck House'",
#    'categories': "'Design'",
#    'Id': '1891267302',
#    'User_id': 'AW3GW105UDEO4',
#    'review/score': 3.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Icon: Art of the Wine Label',
#    'authors': "'Jeffrey Caldewey', 'Chuck House'",
#    'categories': "'Design'",
#    'Id': '1891267302',
#    'User_id': 'AGNEEH9P6IEEJ',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Icon: Art of the Wine Label',
#    'authors': "'Jeffrey Caldewey', 'Chuck House'",
#    'categories': "'Design'",
#    'Id': '1891267302',
#    'User_id': 'A3LNLADU20BG34',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Icon: Art of the Wine Label',
#    'authors': "'Jeffrey Caldewey', 'Chuck House'",
#    'categories': "'Design'",
#    'Id': '1891267302',
#    'User_id': None,
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Icon: Art of the Wine Label',
#    'authors': "'Jeffrey Caldewey', 'Chuck House'",
#    'categories': "'Design'",
#    'Id': '1891267302',
#    'User_id': 'A14OJS0VWMOSWO',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Icon: Art of the Wine Label',
#    'authors': "'Jeffrey Caldewey', 'Chuck House'",
#    'categories': "'Design'",
#    'Id': '1891267302',
#    'User_id': 'A1D0I1Y3RBPOJO',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Icon: Art of the Wine Label',
#    'authors': "'Jeffrey Caldewey', 'Chuck House'",
#    'categories': "'Design'",
#    'Id': '1891267302',
#    'User_id': 'A27548FYCJ658U',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Icon: Art of the Wine Label',
#    'authors': "'Jeffrey Caldewey', 'Chuck House'",
#    'categories': "'Design'",
#    'Id': '1891267302',
#    'User_id': None,
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'U.S. Guns of World War II',
#    'authors': "'Charles W. Pate'",
#    'categories': "'History'",
#    'Id': '1577471059',
#    'User_id': 'A2E0E07A40KMV1',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': "Unrepentant Leftist: A Lawyer's Memoir",
#    'authors': "'Victor Rabinowitz'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '025202253X',
#    'User_id': 'A23FMG0F70HL14',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': "Unrepentant Leftist: A Lawyer's Memoir",
#    'authors': "'Victor Rabinowitz'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '025202253X',
#    'User_id': None,
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': "She's the One",
#    'authors': "'J.J. Murray'",
#    'categories': "'Fiction'",
#    'Id': 'B000OXB4VW',
#    'User_id': 'A24ZTEBRW24SP3',
#    'review/score': 4.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Occupied World (Currents in Canadian Literature)',
#    'authors': "'Alice Major'",
#    'categories': "'Poetry'",
#    'Id': '0888644698',
#    'User_id': 'A14OJS0VWMOSWO',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Jessi and the Jewel Thieves (Baby-Sitters Club Mystery, 8)',
#    'authors': "'Ann M. Martin'",
#    'categories': "'Juvenile Fiction'",
#    'Id': '0590449591',
#    'User_id': 'A1K9504M9GDE2J',
#    'review/score': 1.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Jessi and the Jewel Thieves (Baby-Sitters Club Mystery, 8)',
#    'authors': "'Ann M. Martin'",
#    'categories': "'Juvenile Fiction'",
#    'Id': '0590449591',
#    'User_id': None,
#    'review/score': 3.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Jessi and the Jewel Thieves (Baby-Sitters Club Mystery, 8)',
#    'authors': "'Ann M. Martin'",
#    'categories': "'Juvenile Fiction'",
#    'Id': '0590449591',
#    'User_id': None,
#    'review/score': 3.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Jessi and the Jewel Thieves (Baby-Sitters Club Mystery, 8)',
#    'authors': "'Ann M. Martin'",
#    'categories': "'Juvenile Fiction'",
#    'Id': '0590449591',
#    'User_id': None,
#    'review/score': 5.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Jessi and the Jewel Thieves (Baby-Sitters Club Mystery, 8)',
#    'authors': "'Ann M. Martin'",
#    'categories': "'Juvenile Fiction'",
#    'Id': '0590449591',
#    'User_id': None,
#    'review/score': 4.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Modern typewriting practice,',
#    'authors': "'Gertrude Altholz'",
#    'categories': 'No Category',
#    'Id': 'B0007F6GYC',
#    'User_id': 'A2A1XYSB692L6J',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'The Practice of Network Security: Deployment Strategies for Production Environments',
#    'authors': "'Allan Liska'",
#    'categories': "'Computers'",
#    'Id': '0130462233',
#    'User_id': 'A1TY6L8RIRDSMU',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'The Practice of Network Security: Deployment Strategies for Production Environments',
#    'authors': "'Allan Liska'",
#    'categories': "'Computers'",
#    'Id': '0130462233',
#    'User_id': 'A2T631Q7V2I5YS',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'The Practice of Network Security: Deployment Strategies for Production Environments',
#    'authors': "'Allan Liska'",
#    'categories': "'Computers'",
#    'Id': '0130462233',
#    'User_id': None,
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'The Practice of Network Security: Deployment Strategies for Production Environments',
#    'authors': "'Allan Liska'",
#    'categories': "'Computers'",
#    'Id': '0130462233',
#    'User_id': 'A1L5RDC8H9BB9S',
#    'review/score': 4.0,
#    'ratingsCount': 0.0},
#   {'Title': 'The Practice of Network Security: Deployment Strategies for Production Environments',
#    'authors': "'Allan Liska'",
#    'categories': "'Computers'",
#    'Id': '0130462233',
#    'User_id': 'ALZ6IDYL13NPY',
#    'review/score': 4.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Islamic History: A Framework for Inquiry',
#    'authors': "'R. Stephen Humphreys'",
#    'categories': "'History'",
#    'Id': '0691031452',
#    'User_id': 'AT6Z6G71SNMYM',
#    'review/score': 5.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Islamic History: A Framework for Inquiry',
#    'authors': "'R. Stephen Humphreys'",
#    'categories': "'History'",
#    'Id': '0691031452',
#    'User_id': 'AA6E53C1HY4V6',
#    'review/score': 5.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Islamic History: A Framework for Inquiry',
#    'authors': "'R. Stephen Humphreys'",
#    'categories': "'History'",
#    'Id': '0691031452',
#    'User_id': 'A2LZ5VU1H0MDWU',
#    'review/score': 5.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Islamic History: A Framework for Inquiry',
#    'authors': "'R. Stephen Humphreys'",
#    'categories': "'History'",
#    'Id': '0691031452',
#    'User_id': 'A3F6GIXVE4KYJP',
#    'review/score': 1.0,
#    'ratingsCount': 1.0},
#   {'Title': 'Dead End Bluff',
#    'authors': "'Elizabeth P Witheridge'",
#    'categories': 'No Category',
#    'Id': '0689204809',
#    'User_id': 'A2CB6QOP8FE3UK',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'The Door In The Tree',
#    'authors': None,
#    'categories': 'No Category',
#    'Id': '0743410025',
#    'User_id': 'A14OJS0VWMOSWO',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'The Door In The Tree',
#    'authors': None,
#    'categories': 'No Category',
#    'Id': '0743410025',
#    'User_id': None,
#    'review/score': 4.0,
#    'ratingsCount': 0.0},
#   {'Title': 'The Door In The Tree',
#    'authors': None,
#    'categories': 'No Category',
#    'Id': '0743410025',
#    'User_id': 'A4FX5YCJA630V',
#    'review/score': 2.0,
#    'ratingsCount': 0.0},
#   {'Title': 'The Great Mistake',
#    'authors': "'Jonathan Lee'",
#    'categories': "'Fiction'",
#    'Id': 'B000EFBNXO',
#    'User_id': None,
#    'review/score': 4.0,
#    'ratingsCount': 5.0},
#   {'Title': 'The Great Mistake',
#    'authors': "'Jonathan Lee'",
#    'categories': "'Fiction'",
#    'Id': 'B000EFBNXO',
#    'User_id': 'A18P0T2NZTGWYX',
#    'review/score': 1.0,
#    'ratingsCount': 5.0},
#   {'Title': 'Fundamentals of DC and AC Circuits',
#    'authors': "'David L. Terrell'",
#    'categories': "'Technology & Engineering'",
#    'Id': '0030285380',
#    'User_id': None,
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Fundamentals of DC and AC Circuits',
#    'authors': "'David L. Terrell'",
#    'categories': "'Technology & Engineering'",
#    'Id': '0030285380',
#    'User_id': 'A31T7F9LUN3Q03',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Classic Paul Simon (Paul Simon/Simon & Garfunkel)',
#    'authors': "'Paul Simon'",
#    'categories': "'Music'",
#    'Id': '0825633117',
#    'User_id': 'AQN9WLWWRB02N',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Classic Paul Simon (Paul Simon/Simon & Garfunkel)',
#    'authors': "'Paul Simon'",
#    'categories': "'Music'",
#    'Id': '0825633117',
#    'User_id': 'AYZWWY7U7LI7M',
#    'review/score': 4.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Classic Paul Simon (Paul Simon/Simon & Garfunkel)',
#    'authors': "'Paul Simon'",
#    'categories': "'Music'",
#    'Id': '0825633117',
#    'User_id': 'A2WBODCO91SXCS',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Classic Paul Simon (Paul Simon/Simon & Garfunkel)',
#    'authors': "'Paul Simon'",
#    'categories': "'Music'",
#    'Id': '0825633117',
#    'User_id': 'A3MRQ5ERA4G13H',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Classic Paul Simon (Paul Simon/Simon & Garfunkel)',
#    'authors': "'Paul Simon'",
#    'categories': "'Music'",
#    'Id': '0825633117',
#    'User_id': 'A2GKIWLTVVPT35',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'Classic Paul Simon (Paul Simon/Simon & Garfunkel)',
#    'authors': "'Paul Simon'",
#    'categories': "'Music'",
#    'Id': '0825633117',
#    'User_id': None,
#    'review/score': 3.0,
#    'ratingsCount': 0.0},
#   {'Title': "The Wealthy Banker's Wife: The Assault on Equality in Canada",
#    'authors': "'Linda McQuaig'",
#    'categories': "'Canada'",
#    'Id': '0140230653',
#    'User_id': 'AC06F0LPHI1TW',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': "The Wealthy Banker's Wife: The Assault on Equality in Canada",
#    'authors': "'Linda McQuaig'",
#    'categories': "'Canada'",
#    'Id': '0140230653',
#    'User_id': 'A1UDM7TLZCBSTA',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': "The Wealthy Banker's Wife: The Assault on Equality in Canada",
#    'authors': "'Linda McQuaig'",
#    'categories': "'Canada'",
#    'Id': '0140230653',
#    'User_id': None,
#    'review/score': 1.0,
#    'ratingsCount': 0.0},
#   {'Title': 'I Want to Know How You Found Me',
#    'authors': "'Virginia Macgregor'",
#    'categories': "'Fiction'",
#    'Id': '141372955X',
#    'User_id': 'A3P3P31EEOX2BD',
#    'review/score': 1.0,
#    'ratingsCount': 0.0},
#   {'Title': 'A manual of religious signs',
#    'authors': "'Carter E. Bearden', 'Jerry F. Potter'",
#    'categories': "'Sign language'",
#    'Id': 'B0006YK816',
#    'User_id': 'A2QSPO4ID4ZP1M',
#    'review/score': 5.0,
#    'ratingsCount': 0.0},
#   {'Title': 'How to draw children',
#    'authors': "'Marilyn JS Goodman'",
#    'categories': "'Education'",
#    'Id': 'B00005XH6R',
#    'User_id': 'A8IWWM2VA7CAZ',
#    'review/score': 1.0,
#    'ratingsCount': 0.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A3IYNLYXYE7VGG',
#    'review/score': 5.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A1LKCUQ3SQTHBE',
#    'review/score': 5.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A3B3SUIOW8XPID',
#    'review/score': 2.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A1V5I2Z8HU017P',
#    'review/score': 3.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A2288AHWE49GRG',
#    'review/score': 5.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A2K06KBT06RO4Y',
#    'review/score': 5.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'AANNNS6G3A8XA',
#    'review/score': 5.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'AUXP76NTHG22A',
#    'review/score': 2.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A2SH0VUD9ZXT3V',
#    'review/score': 5.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'AD6FNE7M6SBCD',
#    'review/score': 3.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'AFYX2KRSK9NUU',
#    'review/score': 5.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A3SVIHFID24693',
#    'review/score': 4.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'AD03D7FYL6W4J',
#    'review/score': 5.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A24LNQBHSY9CPF',
#    'review/score': 3.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A29IN1GZHXWKP',
#    'review/score': 5.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A18AJJYQ5PA03O',
#    'review/score': 3.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A1PSRXENN85B77',
#    'review/score': 5.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A1C59H9W1W7Z17',
#    'review/score': 5.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'APG3LVPV0G6YZ',
#    'review/score': 4.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'ARCNXP1PW7LR4',
#    'review/score': 5.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'ABJLRER2PR70K',
#    'review/score': 4.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A3EBY0DNOW140H',
#    'review/score': 5.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A3SE7W116MC397',
#    'review/score': 5.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': None,
#    'review/score': 3.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A3I9DM8V0M6U6H',
#    'review/score': 1.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A3M87TPG0WX5NI',
#    'review/score': 3.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A1TZKV3WQNU3OO',
#    'review/score': 5.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A39TI7AOGB6P5N',
#    'review/score': 1.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A1RAUVCWYHTQI4',
#    'review/score': 1.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'AB6XFSIU03A4I',
#    'review/score': 2.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A2EEFCD3PL182U',
#    'review/score': 5.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A39SLYKJAPRH6',
#    'review/score': 4.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A3NQE2T81EM550',
#    'review/score': 3.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A3VRUSKSLSFVA0',
#    'review/score': 1.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A2MHMIED9NB9LF',
#    'review/score': 5.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A2MURD0BN7B1LG',
#    'review/score': 3.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A3NPMNEOV9X9RM',
#    'review/score': 5.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A33SMZJ9WKY8WM',
#    'review/score': 5.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A1AHEGMLOQRRQ7',
#    'review/score': 4.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A1HX00DL0SZM1G',
#    'review/score': 4.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A3202EWKA5JL4P',
#    'review/score': 5.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'AZGZZDGLEN6RO',
#    'review/score': 5.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A39JE1KM9UZB8Z',
#    'review/score': 5.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'AQMROPVTQTCAD',
#    'review/score': 4.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'AY9X0D827S89',
#    'review/score': 2.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A3EBY0DNOW140H',
#    'review/score': 5.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A37H0NN9DIRQPZ',
#    'review/score': 4.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A13QJ11XIJ03V5',
#    'review/score': 2.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'AE4333YXSR2QC',
#    'review/score': 1.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A2K7GQXVFVNGIU',
#    'review/score': 2.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A3EDDT3FGGZH6B',
#    'review/score': 5.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A2IRZ2Y3CT9OHS',
#    'review/score': 5.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A1R3JW7ZJWJDD8',
#    'review/score': 5.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A3MLCZG6X0RJWM',
#    'review/score': 5.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A3LCC1GEVP2AZ3',
#    'review/score': 3.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A29DLV2Q0ZOWQS',
#    'review/score': 5.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A32CJY2JXGZJIL',
#    'review/score': 4.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A1IOR3OTTUK3O5',
#    'review/score': 2.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A37YRTELWQ5U9P',
#    'review/score': 4.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A7ZJP186A3H2D',
#    'review/score': 5.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A1U1KWUVPES8WE',
#    'review/score': 3.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
#    'categories': "'Fiction'",
#    'Id': 'B000MBOTIG',
#    'User_id': 'A1ZDWD35AZL3S',
#    'review/score': 4.0,
#    'ratingsCount': 18.0},
#   {'Title': 'The Mediterranean Caper (Dirk Pitt Adventure Ser.)',
#    'authors': "'Clive Cussler'",
# ...
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A2OYT6UXIH4WSS',
#    'review/score': 5.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'AHH8F0W59ZLRD',
#    'review/score': 5.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A39XRDN261UYAM',
#    'review/score': 5.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'AHLBHUAY5K28G',
#    'review/score': 1.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'AEFZF3CRXXHMI',
#    'review/score': 5.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A1IIGTB6ZGCLC6',
#    'review/score': 1.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A3IGLWJZF1BL8I',
#    'review/score': 3.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'AWAO301SJWQSF',
#    'review/score': 2.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A3LQXZYW45VAKG',
#    'review/score': 1.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'AYAWJS54W454D',
#    'review/score': 4.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A3GFB42J57J3Z4',
#    'review/score': 1.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': None,
#    'review/score': 5.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': None,
#    'review/score': 5.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A1W2WN97TWJVXB',
#    'review/score': 4.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'APBHVXWWM6QTV',
#    'review/score': 5.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A3A00Q04V6ELGD',
#    'review/score': 4.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'AC2D02BCPRLUY',
#    'review/score': 3.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A15UMKJE4SQEDX',
#    'review/score': 4.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': None,
#    'review/score': 5.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'AAZ0KP2MILC8I',
#    'review/score': 5.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A36YN088H8GNTP',
#    'review/score': 1.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'ATUAOZAZKZWAD',
#    'review/score': 5.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A2QY3QRVOUKS44',
#    'review/score': 5.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': None,
#    'review/score': 5.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'AKDTJJE9TE3DS',
#    'review/score': 5.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': None,
#    'review/score': 2.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A3PY3JONL1GCRI',
#    'review/score': 3.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A359PM8VQT74AO',
#    'review/score': 5.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A311340ET2XIUK',
#    'review/score': 5.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A12X7XHADMYDY0',
#    'review/score': 5.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A1FQNYJUQG1XTS',
#    'review/score': 5.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'AZ5250G2U795I',
#    'review/score': 2.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A3A4NW2UGUX3TF',
#    'review/score': 2.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A1Y0ZGLUSMXNJR',
#    'review/score': 1.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A3B2XI05Z6VH2T',
#    'review/score': 1.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A69HZ5JLSMSCT',
#    'review/score': 1.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A3116ITCY40DC6',
#    'review/score': 1.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A2GOQJ7IS2XCGP',
#    'review/score': 1.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A2RKID3AAP6REO',
#    'review/score': 1.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A3OFPUHNSYJUTN',
#    'review/score': 1.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A3OO5ZH1EFWNS4',
#    'review/score': 1.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A2URNCVRAPAESG',
#    'review/score': 1.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A1B8SX7SFZBOXK',
#    'review/score': 2.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'AV14KSLZNRTXO',
#    'review/score': 1.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A2JZI9UJAPEJYG',
#    'review/score': 2.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A689JV8Y1C9O2',
#    'review/score': 1.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A77Z11MIWQCXX',
#    'review/score': 3.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A37S3ACL57LN62',
#    'review/score': 3.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A16VYBRMNPF69Q',
#    'review/score': 3.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A1MGLHP6QA4Z51',
#    'review/score': 1.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A18WTJO6B8ERSD',
#    'review/score': 1.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': None,
#    'review/score': 1.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A3VETDD4QDA86T',
#    'review/score': 1.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'AQLZZSA62SOKY',
#    'review/score': 2.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': None,
#    'review/score': 5.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A1VUQM42I61B8W',
#    'review/score': 1.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A34X5G34FO522A',
#    'review/score': 1.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A130KC9TDB12I0',
#    'review/score': 4.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'AEYJJF82Q1IXI',
#    'review/score': 5.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A2R4XG0L7Z01V8',
#    'review/score': 4.0,
#    'ratingsCount': 3.0},
#   {'Title': 'Confessions of an Heiress: A Tongue-in-Chic Peek Behind the Pose',
#    'authors': "'Paris Hilton'",
#    'categories': "'Biography & Autobiography'",
#    'Id': '0743266641',
#    'User_id': 'A1YML5JCD52P61',
#    'review/score': 5.0,
#    'ratingsCount': 3.0},
#   ...],
#  'user': 212393}

# %%
import requests
# Envia o POST
response = requests.post(
    "http://127.0.0.1:8000/predict",
    json=payload
)

print(f'Status code: {response.status_code}')
print(f'Json: {response.json()}')

# %% [markdown]
# books = Title, authors, categories
# ratings = id, Title, User_id, review/score

# %%
query = """
SELECT *
FROM ratings
"""

con.execute(query).fetchdf().shape
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# (3000000, 10)

# %%
query = """SELECT 
    b.Title, 
    b.authors, 
    b.categories, 
    r.Id, 
    r.User_id, 
    r."review/score",
    b.ratingsCount
FROM books b
JOIN ratings r ON b.Title = r.Title;"""

df_merged = con.execute(query).fetchdf()

# %%
df_merged
# Out:
#                        Title           authors           categories  \
# 0             Never Cry Wolf  ['Farley Mowat']  ['Animal behavior']
# 1             Never Cry Wolf  ['Farley Mowat']  ['Animal behavior']
# 2             Never Cry Wolf  ['Farley Mowat']  ['Animal behavior']
# 3             Never Cry Wolf  ['Farley Mowat']  ['Animal behavior']
# 4             Never Cry Wolf  ['Farley Mowat']  ['Animal behavior']
# ...                      ...               ...                  ...
# 2999787  Perelandra: A Novel    ['C.S. Lewis']          ['Fiction']
# 2999788  Perelandra: A Novel    ['C.S. Lewis']          ['Fiction']
# 2999789  Perelandra: A Novel    ['C.S. Lewis']          ['Fiction']
# 2999790  Perelandra: A Novel    ['C.S. Lewis']          ['Fiction']
# 2999791  Perelandra: A Novel    ['C.S. Lewis']          ['Fiction']
#
#                  Id         User_id  review/score  ratingsCount
# 0        0316586390  A3D5EO8SCPTX9W           5.0          34.0
# 1        0316586390  A24N8O90K345KV           5.0          34.0
# 2        0316586390  A2CF0A2HR4OS22           5.0          34.0
# 3        0316586390            None           5.0          34.0
# 4        0316586390  A1VXA74UYHCT9E           1.0          34.0
# ...             ...             ...           ...           ...
# 2999787  B000HMK1SW  A3P5U20M8V1MEX           5.0          61.0
# 2999788  B000HMK1SW   APD7XINUVG5AL           5.0          61.0
# 2999789  B000HMK1SW  A1X4JO8EJ1U5BR           5.0          61.0
# 2999790  B000HMK1SW   AZ9E3TNAKALCE           5.0          61.0
# 2999791  B000HMK1SW  A1C3SYP3IDU0HP           5.0          61.0
#
# [2999792 rows x 7 columns]

# %%
df_merged.isna().sum()
# Out:
# Title                 0
# authors          390634
# categories       551290
# Id                    0
# User_id          561774
# review/score          0
# ratingsCount    1360694
# dtype: int64

# %% [markdown]
# I'm going to do here everything that i did before, just refactoring from Pandas to SQL.
#
# "but you are still using pandas"
#
# Yes, I am, but the point of using duckdb to simulate a database is to facilitate. We can't use and it's not realistic focusing only on pandas or polars.
#
# I'm currently testing Duckdb with pandas because in the previous version of this project i had to use pandas. Polars is not so flexibe right now.
#
# This notebook will test and then I will refactor the code

# %%
df_merged['categories'] = df_merged['categories'].fillna('No Category')

df_merged['ratingsCount'] = df_merged['ratingsCount'].fillna(0)

# %%
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder, StandardScaler, LabelEncoder
import numpy as np
import joblib

# 0. Preprocessing the strings

df_merged['categories'] = df_merged['categories'].str.replace('[', '', regex=False).str.replace(']', '', regex=False)
df_merged['authors'] = df_merged['authors'].str.replace('[', '', regex=False).str.replace(']', '', regex=False)

# 1. Ordinal Encoder

encoder = joblib.load(r'C:\Users\lucas\Documents\GitHub\Recommind\models\encoding_models\ordinal_encoder.joblib')
encoded = encoder.fit_transform(df_merged[['User_id', 'Id', 'categories', 'authors']].to_numpy())

df_encoded = df_merged.copy()
df_encoded['User_id'] = encoded[:, 0].astype(int)
df_encoded['Id'] = encoded[:, 1].astype(int)
df_encoded['categories'] = encoded[:, 2].astype(int)
df_encoded['authors'] = encoded[:, 3].astype(int)


df_encoded = df_encoded[(df_encoded['User_id'] != -1) & (df_encoded['Id'] != -1)]

n_users = df_encoded['User_id'].max() + 1
n_items = df_encoded['Id'].max() + 1

print(f"n_users = {n_users}, n_items = {n_items}")
# Out:
# n_users = 1008962, n_items = 221989

# %% [markdown]
# End!
#
# The purpose of this notebook was testing Duckdb.
